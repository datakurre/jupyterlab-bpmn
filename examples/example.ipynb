# %%
bpmn = open("./examples/fleamarket-submission.bpmn").read()

# %%
from IPython.display import display
import json

data = json.dumps({
    "style": {
        "height": "400px"
    }
})

# %%
display_id = "my-display-id"
handle = display({"application/bpmn+xml": bpmn, "application/bpmn+json": data}, raw=True, display_id=display_id)

# %%
from IPython.display import update_display

tasks = [
    "robot_search",
    "robot_count",
    "robot_save_item",
    "robot_review",
    "robot_items_excel",
    "robot_create_json"
]

data = json.dumps({
    "colors": {
        task: {
           "stroke": "#ffffff",
           "fill": "#000000",
        } for task in tasks
    }
})

update_display({"application/bpmn+xml": None, "application/bpmn+json": data}, raw=True, display_id=display_id)
