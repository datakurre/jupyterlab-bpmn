# %%
bpmn = open("fleamarket-submission.bpmn").read()

# %%
from IPython.display import display
import json

data = json.dumps({
    "style": {
        "height": "400px"
    },
    "zoom": 0.6
})

# %%
display_id = "my-display-id"
handle = display({"application/bpmn+xml": bpmn, "application/bpmn+json": data}, raw=True, display_id=display_id)

# %%
from IPython.display import update_display

data = json.dumps({
    "style": {
        "height": "400px"
    },
    "colors": {
        "Event_0vcrohg": {  # start
            "stroke": "#000000",
            "fill": "#00ff00",
        },
        "Event_1il4m3d": {  # end
            "stroke": "#000000",
            "fill": "#b94a48",
        },
        "Event_0kimgio": {  # end
            "stroke": "#000000",
            "fill": "#b94a48",
        }
    },
    "activities": [{
        "activityId": "Event_0vcrohg",
        "startTime": "2022-04-03T12:32:24.383+0200",
        "endTime": "2022-04-03T12:32:24.384+0200",
    }, {
        "activityId": "Gateway_00qq4t2",
        "startTime": "2022-04-03T12:32:24.385+0200",
        "endTime": "2022-04-03T12:32:24.385+0200",
    }, {
        "activityId": "robot_search",
        "startTime": "2022-04-03T12:33:24.385+0200",
    }],
    "incidents": [{
        "activityId": "robot_search",
        "incidentMessage": "DRAGONS",
    }]
})

update_display({"application/bpmn+xml": bpmn, "application/bpmn+json": data}, raw=True, display_id=display_id)
